# %%
# !wget https://github.com/rickiepark/machine-learning-with-python-cookbook/raw/master/images/plane.jpg -O plane.jpg
# Out:
# --2024-07-23 17:21:23--  https://github.com/rickiepark/machine-learning-with-python-cookbook/raw/master/images/plane.jpg
# Resolving github.com (github.com)... 20.200.245.247
# Connecting to github.com (github.com)|20.200.245.247|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rickiepark/machine-learning-with-python-cookbook/master/images/plane.jpg [following]
# --2024-07-23 17:21:23--  https://raw.githubusercontent.com/rickiepark/machine-learning-with-python-cookbook/master/images/plane.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4937732 (4.7M) [image/jpeg]
# Saving to: 'plane.jpg'
#
# plane.jpg           100%[===================>]   4.71M  13.0MB/s    in 0.4s
#
# ...

# %%
# !wget https://github.com/rickiepark/machine-learning-with-python-cookbook/raw/master/images/plane_256x256.jpg -O plane_256x256.jpg
# Out:
# --2024-07-23 17:21:25--  https://github.com/rickiepark/machine-learning-with-python-cookbook/raw/master/images/plane_256x256.jpg
# Resolving github.com (github.com)... 20.200.245.247
# Connecting to github.com (github.com)|20.200.245.247|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rickiepark/machine-learning-with-python-cookbook/master/images/plane_256x256.jpg [following]
# --2024-07-23 17:21:25--  https://raw.githubusercontent.com/rickiepark/machine-learning-with-python-cookbook/master/images/plane_256x256.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22974 (22K) [image/jpeg]
# Saving to: 'plane_256x256.jpg'
#
# ...

# %%
# 라이브러리 임포트해서 버전 체크
import cv2
cv2.__version__
# Out:
# '4.10.0'

# %%
# 이미지 파일 읽기
image = cv2.imread('plane.jpg')

# %%
# 이미지를 회색으로 변환
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# 이미지 시각화 (코랩에서는 실행이 안됨)
cv2.imshow('Gray Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # MATPLOTLIB으로 시각화

# %%
# 흑백이미지를 출력
import matplotlib.pyplot as plt

plt.imshow(gray_image, cmap='gray')
plt.show()

# %%
# 맷플랏리브로 이미지 시각화
import matplotlib.pyplot as plt
plt.imshow(image, cmap='gray')
plt.show()

# %%
# 컬러이미지를 출력
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image2)
plt.show()

# %%
# 흑백으로 읽어와서 시각화
image_gray = cv2.imread('plane.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(image_gray, cmap='gray')
plt.show()

# %%
# 컬러로 읽어와서 흑백으로 변화 후 시각화
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(image_gray, cmap='gray')
plt.show()

# %%
# 컬러로 읽어서 RGB로 변경해서 시각화
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.show()

# %% [markdown]
# # 이미지 저장

# %%
# 이미지 저장
cv2.imwrite('plane_rgb.jpg', image_rgb)
# Out:
# True

# %% [markdown]
# # 이미지 크기 변경

# %%
# 이미지 크기를 50, 50으로 변경
image_50x50 = cv2.resize(image, (50, 50))
plt.imshow(image_50x50)
plt.show()

# %% [markdown]
# # 이미지 크기 변경

# %%
# 256x256 이미지 읽기
img = cv2.imread('plane_256x256.jpg', cv2.IMREAD_GRAYSCALE) # BGR
img.shape
# Out:
# (256, 256)

# %%
# 이미지 크기를 50, 50으로 변경
img_50x50 = cv2.resize(img, (50, 50))
plt.imshow(img_50x50, cmap='gray')
plt.show()

# %% [markdown]
# # 이미지 자르기

# %%
img_cropped = img[:, :128]
plt.imshow(img_cropped, cmap='gray')
plt.show()
img_cropped.shape
# Out:
# (256, 128)

# %% [markdown]
# # 이미지 흐리게 하기

# %%
# 이미지 흐리게 하기
img_blur = cv2.blur(img, (5,5))
plt.imshow(img_blur, cmap='gray')
plt.show()

# %%
# 커널을 이용해서 흐리게 하기
import numpy as np
kernel = np.ones((5,5)) / 25.0 # 모두 더하면 1이 되도록 정규화
kernel
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]])

# %%
kernel.sum() # 전체를 합치면 1이 됨
# Out:
# 1.0

# %%
# 커널 적용
img_kernel = cv2.filter2D(img, -1, kernel)

# %%
# 커널 적용된 이미지 출력
plt.imshow(img_kernel, cmap="gray"), plt.xticks([]),
plt.yticks([])
plt.show()

# %%
# 가우시안 블러
img_gau_blur = cv2.GaussianBlur(img, (5,5), 0)
plt.imshow(img_gau_blur, cmap="gray"), plt.xticks([]),
plt.yticks([])
plt.show()

# %% [markdown]
# # 선명한 이미지 처리

# %%
# 이미지 읽기
img = cv2.imread('plane.jpg', cv2.IMREAD_GRAYSCALE)

# %%
# 선명한 이미지를 위한 커널 생성
kernel = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])

# %%
# 이미지에 커널 적용
img_sharp = cv2.filter2D(img, -1, kernel)

# %%
# 이미지에 커널 적용
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original Image')

ax[1].imshow(img_sharp, cmap='gray')
ax[1].set_title('Sharp Image')
# Out:
# Text(0.5, 1.0, 'Sharp Image')

# %% [markdown]
# # 이미지 대비 처리

# %%
plt.hist(img.ravel(), bins=256)
plt.show()

# %%
# 이미지를 대비해서 향상
img_enhance = cv2.equalizeHist(img)
plt.imshow(img_enhance, cmap='gray')
plt.show()

# %% [markdown]
# # 이미지 대비 처리 (YUV 이용)

# %%
# 이미지 YUV로 읽기
img = cv2.imread('plane.jpg')
img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:, :, 0])
img_rgb = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2RGB)

plt.imshow(img_rgb)
plt.show()

# %%
# 이미지에 커널 적용
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original Image')

ax[1].imshow(img_rgb, cmap='gray')
ax[1].set_title('Sharp Image')
# Out:
# Text(0.5, 1.0, 'Sharp Image')

# %%
# 150이상이면 255로 이진화
img = cv2.imread('plane.jpg', cv2.IMREAD_GRAYSCALE) # 흑백으로 이미지를 읽기

# 기준점 이상인 것만 255로 할당
ret, img_binary = cv2.threshold(img, 150, 255, cv2.THRESH_BINARY)
plt.imshow(img_binary, cmap='gray')
plt.show()

# %%
# Adaptive Thresholding
# 적응적 임계처리 적용
max_output_value = 255
neighborhood_size = 99
subtract_from_mean = 10
image_binarized = cv2.adaptiveThreshold(img,
                                        max_output_value, # 출력 픽셀 강도의 최댓값
                                        cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                        cv2.THRESH_BINARY,
                                        neighborhood_size,
                                        subtract_from_mean)

# 이미지 출력
plt.imshow(image_binarized, cmap="gray"), plt.axis("off")
plt.show()
